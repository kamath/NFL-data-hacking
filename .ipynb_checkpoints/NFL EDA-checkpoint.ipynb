# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import operator

# %%
#Exploring some basic elements spanning all players
basic = pd.read_csv('Basic_Stats.csv', encoding='utf8')
playerdict = {}
qualities = ('Name', 'Experience', 'Height (inches)', 'Weight (lbs)', 'Position')
for i in range(len(basic['Current Status'])):
    if basic['Current Status'][i] == 'Active':
        tor = {}
        for a in qualities:
            tor[a] = basic[a][i]
        playerdict[basic['Player Id'][i]] = tor

# %% [markdown]
# ## Exploring passing scores
# ![passing.png](passing.png)

# %%
#Exploring passing
'''
· TD Pass = 4pts
· Every 25 passing yards = 1pts
· 2pt Passing Conversion = 2pts
· Interceptions Thrown = -2pts
'''
passes = pd.read_csv('Career_Stats_Passing.csv', encoding='utf8')
passdict = {}
qualities = ('Games Played', 'Passes Attempted', 'Completion Percentage', 'Pass Attempts Per Game', 'TD Passes', 'Percentage of TDs per Attempts', 'Passes Longer than 20 Yards', 'Ints', 'Int Rate', 'Passing Yards Per Attempt')
for i in range(len(passes['Team'])):
    if passes['Player Id'][i] in playerdict:
        tor = {}
        for a in qualities:
            tor[a] = float(passes[a][i]) if passes[a][i] != '--' else 0
        if passes['Player Id'][i] in passdict:
            s = passdict[passes['Player Id'][i]]
            d = {}
            for key, val in s.items():
                if key != 'times':
                    passdict[passes['Player Id'][i]][key] = ((s[key]*s['times'])+tor[key])/(s['times']+1)
            passdict[passes['Player Id'][i]]['times'] += 1
        else:
            tor['times'] = 1
            passdict[passes['Player Id'][i]] = tor
            passdict[passes['Player Id'][i]]['times'] = 1
pass_scores = {}
for key, val in passdict.items():
    g, att, p_c, _, TD, p_TD, p_20, i, p_i, py = qualities
    p = passdict[key]
    pass_scores[key] = ((p[att]*p[py]*p[p_c])/(p[g]*100)) + (p[TD]*p[p_TD]*4/(p[g]*100)) + (2*p[p_20]*p[p_c]/(p[g]*100)) - (2*p[i]*p[p_i]/(p[g]*100))
top = sorted(pass_scores.items(), key=operator.itemgetter(1))
top.reverse()
positions = {}
for a in top:
    if playerdict[a[0]]['Position'] not in positions:
        positions[playerdict[a[0]]['Position']] = 1
    else:
        positions[playerdict[a[0]]['Position']] += 1
print(positions)

top_by_position = {}

for key in positions.keys():
    top_by_position[key] = []

for a in top:
    pos = playerdict[a[0]]['Position']
    #Limit it to 12 since there's only 12 people in my league
    if len(top_by_position) < 12:
        top_by_position[pos].append(a)

for key, val in top_by_position.items():
    print('Top', key+'s for passing')
    for a in val[:12]:
        print(playerdict[a[0]]['Position'], '-', playerdict[a[0]]['Name'], '\nScore:', a[1])
    print('')
# Out:
# {'QB': 76, 'WR': 35, 'P': 14, 'RB': 11, 'SS': 2, 'NT': 1, 'K': 6, 'CB': 1, 'TE': 1, 'ILB': 1}
# Top QBs for passing
# QB - Brees, Drew
# Score: 190.9470415973713
# QB - Ryan, Matt
# Score: 176.25137245696396
# QB - Cousins, Kirk
# Score: 175.09741808695662
# QB - Stafford, Matthew
# Score: 168.76040173451838
# QB - Roethlisberger, Ben
# Score: 167.9310715496562
# QB - Luck, Andrew
# Score: 163.75400502857138
# QB - Prescott, Dak
# Score: 159.10449999999997
# QB - Brady, Tom
# Score: 157.93311046676294
# QB - Rivers, Philip
# Score: 156.51541969428004
# QB - Winston, Jameis
# Score: 155.69698125000002
# QB - Tannehill, Ryan
# Score: 155.67245200000002
# QB - Dalton, Andy
# Score: 155.0574910394265
#
# Top WRs for passing
# WR - Pryor, Terrelle
# Score: 9.949116235294117
# WR - McEvoy, Tanner
# Score: 3.2142857142857144
# WR - Sanu, Mohamed
# Score: 1.1154555555555556
# WR - Snead, Willie
# Score: 0.5166666666666667
# WR - Kerley, Jeremy
# Score: 0.21975308641975308
# WR - Lee, Marqise
# Score: 0.10826210826210825
# WR - Meredith, Cameron
# Score: 0.1
# WR - Brown, Antonio
# Score: 0.051929682764194796
# WR - Landry, Jarvis
# Score: 0.04166666666666667
# WR - Daniels, B.J.
# Score: 0.02734375
# WR - Tate, Golden
# Score: 0.012514439738159416
# WR - Baldwin, Doug
# Score: 0.011524822695035462
#
# Top Ps for passing
# P - Dixon, Riley
# Score: 1.0
# P - Hekker, Johnny
# Score: 0.6825799999999999
# P - Way, Tress
# Score: 0.08564814814814814
# P - Quigley, Ryan
# Score: 0.037647058823529415
# P - Martin, Sam
# Score: 0.0341796875
# P - Ryan, Jon
# Score: 0.018512396694214877
# P - Anger, Bryan
# Score: 0.0095
# P - Lechler, Shane
# Score: 0.005148744072792515
# P - Koch, Sam
# Score: 0.0018782870022539446
# P - Colquitt, Dustin
# Score: 0.00021929824561403506
# P - Lee, Andy
# Score: 0.0
# P - Jones, Donnie
# Score: 0.0
#
# Top RBs for passing
# RB - James, Mike
# Score: 0.048913043478260865
# RB - Powell, Bilal
# Score: 0.015765765765765764
# RB - McFadden, Darren
# Score: 0.012103606874848703
# RB - Murray, DeMarco
# Score: 0.005621693121693121
# RB - Lynch, Marshawn
# Score: 0.005039370078740157
# RB - McKinnon, Jerick
# Score: 0.0
# RB - Forte, Matt
# Score: 0.0
# RB - Johnson, Duke
# Score: 0.0
# RB - Cadet, Travaris
# Score: 0.0
# RB - Williams, Jonathan
# Score: 0.0
# RB - Bell, Le'Veon
# Score: 0.0
#
# Top SSs for passing
# SS - Golden, Robert
# Score: 0.018421052631578946
# SS - Weddle, Eric
# Score: 0.0
#
# Top NTs for passing
# NT - Poe, Dontari
# Score: 0.011282051282051283
#
# Top Ks for passing
# K - Santos, Cairo
# Score: 0.006944444444444444
# K - Vinatieri, Adam
# Score: 0.0006197095815551893
# K - Dawson, Phil
# Score: 0.0001106243639099075
# K - Gould, Robbie
# Score: 0.0
# K - Tucker, Justin
# Score: 0.0
# K - Prater, Matt
# Score: 0.0
#
# Top CBs for passing
# CB - Peterson, Patrick
# Score: 0.004918981481481482
#
# Top TEs for passing
# TE - Witten, Jason
# Score: 0.0016015374759769377
#
# Top ILBs for passing
# ILB - Morrison, Antonio
# Score: 0.0

# %% [markdown]
# ## Exploring Rushing
# ![rushing.png](rushing.png)

# %%
#Exploring rushing
'''
· TD Rush = 6pts
· Every 10 rushing yards = 1pt
· 2pt Rushing Conversion = 2pts
'''
rushes = pd.read_csv('Career_Stats_Rushing.csv', encoding='utf8')
rushdict = {}
qualities = ('Games Played', 'Rushing Yards', 'Rushing TDs')
for i in range(len(rushes['Team'])):
    if rushes['Player Id'][i] in playerdict:
        tor = {}
        for a in qualities:
            tor[a] = float(str(rushes[a][i]).replace(',','')) if rushes[a][i] != '--' else 0
        if rushes['Player Id'][i] in rushdict:
            s = rushdict[rushes['Player Id'][i]]
            d = {}
            for key, val in s.items():
                if key != 'times':
                    rushdict[rushes['Player Id'][i]][key] = ((s[key]*s['times'])+tor[key])/(s['times']+1)
            rushdict[rushes['Player Id'][i]]['times'] += 1
        else:
            tor['times'] = 1
            rushdict[rushes['Player Id'][i]] = tor
            rushdict[rushes['Player Id'][i]]['times'] = 1
rush_scores = {}
for key, val in rushdict.items():
    g, y, TD = qualities
    p = passdict[key]
    pass_scores[key] = ((p[att]*p[py]*p[p_c])/(p[g]*100)) + (p[TD]*p[p_TD]*4/(p[g]*100)) + (2*p[p_20]*p[p_c]/(p[g]*100)) - (2*p[i]*p[p_i]/(p[g]*100))
top = sorted(pass_scores.items(), key=operator.itemgetter(1))
top.reverse()
positions = {}
for a in top:
    if playerdict[a[0]]['Position'] not in positions:
        positions[playerdict[a[0]]['Position']] = 1
    else:
        positions[playerdict[a[0]]['Position']] += 1
print(positions)

top_by_position = {}

for key in positions.keys():
    top_by_position[key] = []

for a in top:
    pos = playerdict[a[0]]['Position']
    #Limit it to 12 since there's only 12 people in my league
    if len(top_by_position) < 12:
        top_by_position[pos].append(a)

for key, val in top_by_position.items():
    print('Top', key+'s for passing')
    for a in val[:12]:
        print(playerdict[a[0]]['Position'], '-', playerdict[a[0]]['Name'], '\nScore:', a[1])
    print('')
# Out:
# {'tomsavage/2543640': {'Games Played': 2.5, 'Rushing Yards': 3.0, 'Rushing TDs': 0.0, 'times': 2}, 'brandontate/81306': {'Games Played': 14.125, 'Rushing Yards': 17.75, 'Rushing TDs': 0.0, 'times': 8}, 'kenyandrake/2555230': {'Games Played': 16.0, 'Rushing Yards': 179.0, 'Rushing TDs': 2.0, 'times': 1}, 't.j.jones/2543836': {'Games Played': 6.5, 'Rushing Yards': -1.5, 'Rushing TDs': 0.0, 'times': 2}, 'amaricooper/2552487': {'Games Played': 16.0, 'Rushing Yards': -1.5, 'Rushing TDs': 0.0, 'times': 2}, 'dwaynewashington/2556118': {'Games Played': 12.0, 'Rushing Yards': 265.0, 'Rushing TDs': 1.0, 'times': 1}, 'jimmygraham/497236': {'Games Played': 15.0, 'Rushing Yards': 0.42857142857142855, 'Rushing TDs': 0.0, 'times': 7}, 'andrewilliams/2543565': {'Games Played': 11.0, 'Rushing Yards': 355.0, 'Rushing TDs': 2.6666666666666665, 'times': 3}, 'julianedelman/238498': {'Games Played': 12.875, 'Rushing Yards': 32.125, 'Rushing TDs': 0.0, 'times': 8}, "pato'donnell/2543611": {'Games Played': 15.666666666666666, 'Rushing Yards': -4.0, 'Rushing TDs': 0.0, 'times': 3}, 'jamisoncrowder/2552415': {'Games Played': 16.0, 'Rushing Yards': 0.0, 'Rushing TDs': 0.0, 'times': 2}, 'braxtonmiller/2555348': {'Games Played': 10.0, 'Rushing Yards': 0.0, 'Rushing TDs': 0.0, 'times': 1},